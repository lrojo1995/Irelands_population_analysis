# %% [markdown]
# ## Population in Ireland: Where are we heading to?

# %% [markdown]
# ### Scenario
# Human capital is an important bed rock of any stable economy, a large population means more workers and customers which ultimately boosts a country’s GDP (World101, 2022).
# As stated by (Wilmoth, Menozzi and Bassarsky, 2022) world population is expected to peak around 2100 at a level of almost 11 billion. (OECD and UN, 2023) both reported a country requires a birth rate of 2.1 children per woman to maintain a healthy population growth. However, Ireland has recorded a progressive decline in its birth rate since 1970 but were still within a healthy birth rate.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Data source
# - Independent features: The dataset for this analysis is going to be gotten from the Central Statistics Office (CSO), Ireland. The CSO is responsible for collection, compilation, extraction and dissemination of high-quality data used for analysis of economic and social important topics.
#
# - Dependent feature:

# %% [markdown]
# ### Approach
# At this first stage we will approach the case aiming to fit a Random Forest Regressor Machine Learning model, due to its multiple benefits like low risk of overfitting, easy to determine feature importance and not needing considerable pre-processing work, to name a few.

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm
import pmdarima as pm
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import cross_val_score
from sklearn import metrics


import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ### Loading our independent features

# %%
df = pd.read_csv('Total Births, Deaths and Marriages Registered.csv')
df.head(-5)
# Out:
#                           Statistic Label Quarter  State    UNIT   VALUE
# 0                    Marriages Registered  1960Q1  State  Number  2987.0
# 1                    Marriages Registered  1960Q2  State  Number  3501.0
# 2                    Marriages Registered  1960Q3  State  Number  5900.0
# 3                    Marriages Registered  1960Q4  State  Number  3106.0
# 4                    Marriages Registered  1961Q1  State  Number  2179.0
# ...                                   ...     ...    ...     ...     ...
# 4544  Average age of mothers giving birth  2020Q4  State  Number     NaN
# 4545  Average age of mothers giving birth  2021Q1  State  Number     NaN
# 4546  Average age of mothers giving birth  2021Q2  State  Number     NaN
# 4547  Average age of mothers giving birth  2021Q3  State  Number     NaN
# 4548  Average age of mothers giving birth  2021Q4  State  Number     NaN
#
# [4549 rows x 5 columns]

# %% [markdown]
# ### Data dictionary

# %% [markdown]
# ##### Statistic Label
# - Marriages Registered
# - Marriage Rate Registered per 1000 Estimated Population
# - Deaths Registered
# - Death Rate Registered per 1000 Estimated Population
# - Deaths of Infants under 1 Year Registered per 1000 Births
# - Births Registered
# - Birth Rate Registered per 1000 Estimated Population
# - Opposite sex marriages
# - Same sex marriages
# - Civil partnerships
# - Births registered that were first births
# - Births registered outside marriage
# - Opposite sex marriage rate
# - Same sex marriage rate
# - Civil partnership marriage rate
# - Percentage of first births registered
# - Percentage of births registered outside marriage
# - Average age of mothers giving birth
#
# ##### Quarter
# Years from 1960 (Q1) to 2023 (Q1); each year has 4 quarters (Q1, Q2, Q3 and Q4).
#
# ##### State
# - State
#
# ##### UNIT
# These represents the metric of the next feature (VALUE).
# - Number
# - %
#
# ##### VALUE
# Values regarding the Statistic Label feature.

# %% [markdown]
# ### EDA and data preparation

# %%
df.info() # Check the shape and and types of our data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4554 entries, 0 to 4553
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Statistic Label  4554 non-null   object
#  1   Quarter          4554 non-null   object
#  2   State            4554 non-null   object
#  3   UNIT             4554 non-null   object
#  4   VALUE            1826 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 178.0+ KB

# %%
df.isnull().mean()*100 # Porcentage of missing data
# Out:
# Statistic Label     0.000000
# Quarter             0.000000
# State               0.000000
# UNIT                0.000000
# VALUE              59.903382
# dtype: float64

# %%
df['Statistic Label'].unique() # Check the categories in our Statistic Label.
# Out:
# array(['Marriages Registered',
#        'Marriage Rate Registered per 1000 Estimated Population',
#        'Deaths Registered',
#        'Death Rate Registered per 1000 Estimated Population',
#        'Deaths of Infants under 1 Year Registered per 1000 Births',
#        'Births Registered',
#        'Birth Rate Registered per 1000 Estimated Population',
#        'Opposite sex marriages', 'Same sex marriages',
#        'Civil partnerships', 'Births registered that were first births',
#        'Births registered outside marriage', 'Opposite sex marriage rate',
#        'Same sex marriage rate', 'Civil partnership marriage rate',
#        'Percentage of first births registered',
#        'Percentage of births registered outside marriage',
#        'Average age of mothers giving birth'], dtype=object)

# %% [markdown]
# Let's confirm that our 'State' feature only has 1 category, and in that case we can drop the feature due that it doesn't add any value to our analysis.

# %%
df['State'].unique()
# Out:
# array(['State'], dtype=object)

# %%
df.drop(columns='State', inplace=True) # Dropping the 'State' feature.
df.head()
# Out:
#         Statistic Label Quarter    UNIT   VALUE
# 0  Marriages Registered  1960Q1  Number  2987.0
# 1  Marriages Registered  1960Q2  Number  3501.0
# 2  Marriages Registered  1960Q3  Number  5900.0
# 3  Marriages Registered  1960Q4  Number  3106.0
# 4  Marriages Registered  1961Q1  Number  2179.0

# %% [markdown]
# Since we are looking for values in numbers and not represented in percentages, we will drop all the rows that has % in our 'UNIT' feature, after performing this task, we can now drop the 'UNIT' feature because we know that we only have values represented in numbers.

# %%
df['UNIT'].unique()
# Out:
# array(['Number', '%'], dtype=object)

# %%
df = df[df['UNIT'].str.contains('%')==False]
df['UNIT'].unique()
# Out:
# array(['Number'], dtype=object)

# %%
df.drop(columns='UNIT', inplace=True)
df.head()
# Out:
#         Statistic Label Quarter   VALUE
# 0  Marriages Registered  1960Q1  2987.0
# 1  Marriages Registered  1960Q2  3501.0
# 2  Marriages Registered  1960Q3  5900.0
# 3  Marriages Registered  1960Q4  3106.0
# 4  Marriages Registered  1961Q1  2179.0

# %% [markdown]
# Standardize in lower case letters in a new feature our 'Statistic Label' feature to manage all the categories easier.

# %%
df['label_lc'] = df['Statistic Label'].apply(lambda x: ' '.join(x.lower() for x in x.split())) # put everything in lower case
df[['label_lc']].head()
# Out:
#                label_lc
# 0  marriages registered
# 1  marriages registered
# 2  marriages registered
# 3  marriages registered
# 4  marriages registered

# %% [markdown]
# Since we are analysing the population change per year, we do not need the values per quater, therefore we will remove Q1, Q2, Q3 and Q4 from the Quater column and then we will be able to asign the column as a integer (whole numbers).

# %%
df.rename(columns={"Quarter": "year"}, inplace=True)
df.rename(columns={"VALUE": "value"}, inplace=True)

# %%
df['year'] = df['year'].str[:-2] # Remove the 2 last characters
df['year']
# Out:
# 0       1960
# 1       1960
# 2       1960
# 3       1960
# 4       1961
#         ...
# 4549    2022
# 4550    2022
# 4551    2022
# 4552    2022
# 4553    2023
# Name: year, Length: 3289, dtype: object

# %%
df['year'] = df['year'].astype(int) # Assign Quarter column as a type integer
df.dtypes
# Out:
# Statistic Label     object
# year                 int32
# value              float64
# label_lc            object
# dtype: object

# %% [markdown]
# Due to we have a dataset which years are divided per quarter, we need to sum each quarter value into one single row, then, we can remove every category in our 'label_lc' feature that we do not need, we only require the overall value of births, deaths and marriages.

# %%
df_group = df.groupby(['year','label_lc'])['value'].sum()
df_group.head(20)
# Out:
# year  label_lc
# 1960  average age of mothers giving birth                              0.0
#       birth rate registered per 1000 estimated population             85.7
#       births registered                                            60730.0
#       births registered outside marriage                               0.0
#       births registered that were first births                         0.0
#       civil partnerships                                               0.0
#       death rate registered per 1000 estimated population             45.9
#       deaths of infants under 1 year registered per 1000 births      117.5
#       deaths registered                                            32658.0
#       marriage rate registered per 1000 estimated population          21.8
#       marriages registered                                         15494.0
#       opposite sex marriages                                           0.0
# ...

# %%
df = df[df['label_lc'].str.contains('average age of mothers giving birth')==False]
df = df[df['label_lc'].str.contains('births registered outside marriage')==False]
df = df[df['label_lc'].str.contains('births registered that were first births')==False]
df = df[df['label_lc'].str.contains('civil partnerships')==False]
df = df[df['label_lc'].str.contains('opposite sex marriages')==False]
df = df[df['label_lc'].str.contains('same sex marriages')==False]
df = df[df['label_lc'].str.contains('birth rate registered per 1000 estimated population')==False]
df = df[df['label_lc'].str.contains('death rate registered per 1000 estimated population')==False]
df = df[df['label_lc'].str.contains('deaths of infants under 1 year registered per 1000 births')==False]
df = df[df['label_lc'].str.contains('marriage rate registered per 1000 estimated population')==False]

df['label_lc'].unique()
# Out:
# array(['marriages registered', 'deaths registered', 'births registered'],
#       dtype=object)

# %% [markdown]
# Assign VALUE column as a type integer, since a birth or death can only be an integer.

# %%
df['value'] = df['value'].astype(int)
df.dtypes
# Out:
# Statistic Label    object
# year                int32
# value               int32
# label_lc           object
# dtype: object

# %% [markdown]
# Now we can cut our dataset by removing the year 2023, owing to the fact that we are analysing from 1960 to 2022.

# %%
df = df.query('year != 2023')
df['year'].unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
df.head()
# Out:
#         Statistic Label  year  value              label_lc
# 0  Marriages Registered  1960   2987  marriages registered
# 1  Marriages Registered  1960   3501  marriages registered
# 2  Marriages Registered  1960   5900  marriages registered
# 3  Marriages Registered  1960   3106  marriages registered
# 4  Marriages Registered  1961   2179  marriages registered

# %% [markdown]
# Remove the feature 'Statistic Label' since we already have a lower case feature with the same data.

# %%
df.drop(columns='Statistic Label', inplace=True)
df.head()
# Out:
#    year  value              label_lc
# 0  1960   2987  marriages registered
# 1  1960   3501  marriages registered
# 2  1960   5900  marriages registered
# 3  1960   3106  marriages registered
# 4  1961   2179  marriages registered

# %%
df_group = df.groupby(['year','label_lc'], as_index=False)['value'].sum()
df_group.head(20)
# Out:
#     year              label_lc  value
# 0   1960     births registered  60730
# 1   1960     deaths registered  32658
# 2   1960  marriages registered  15494
# 3   1961     births registered  59826
# 4   1961     deaths registered  34548
# 5   1961  marriages registered  15140
# 6   1962     births registered  61611
# 7   1962     deaths registered  33643
# 8   1962  marriages registered  15409
# 9   1963     births registered  62966
# 10  1963     deaths registered  33558
# 11  1963  marriages registered  15298
# 12  1964     births registered  64008
# 13  1964     deaths registered  32473
# 14  1964  marriages registered  15941
# 15  1965     births registered  63443
# 16  1965     deaths registered  32778
# 17  1965  marriages registered  16664
# 18  1966     births registered  62143
# 19  1966     deaths registered  34725

# %%
df_group['label_lc'].replace('births registered','births_registered', inplace=True)
df_group['label_lc'].replace('deaths registered','deaths_registered', inplace=True)
df_group['label_lc'].replace('marriages registered','marriages_registered', inplace=True)
df_group.head()
# Out:
#    year              label_lc  value
# 0  1960     births_registered  60730
# 1  1960     deaths_registered  32658
# 2  1960  marriages_registered  15494
# 3  1961     births_registered  59826
# 4  1961     deaths_registered  34548

# %%
df_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      189 non-null    int32
#  1   label_lc  189 non-null    object
#  2   value     189 non-null    int32
# dtypes: int32(2), object(1)
# memory usage: 3.1+ KB

# %%
df_group.isnull().mean()*100 # Porcentage of missing data
# Out:
# year        0.0
# label_lc    0.0
# value       0.0
# dtype: float64

# %% [markdown]
# At this point of our analysis, we will need to split our 'label_lc' categories into different datasets with the goal of making each category a feature of its own in a new dataset.

# %%
df_births = pd.DataFrame() # Create an empty data frame to store the births values
df_deaths = pd.DataFrame() # Create an empty data frame to store the deaths values
df_marriages = pd.DataFrame() # Create an empty data frame to store the marriages values

# %%
df_births = df_group.loc[df_group['label_lc'] == 'births_registered']
df_deaths = df_group.loc[df_group['label_lc'] == 'deaths_registered']
df_marriages = df_group.loc[df_group['label_lc'] == 'marriages_registered']

# %%
df_births.rename(columns={"value": "births"}, inplace=True)
df_births.head()
# Out:
#     year           label_lc  births
# 0   1960  births_registered   60730
# 3   1961  births_registered   59826
# 6   1962  births_registered   61611
# 9   1963  births_registered   62966
# 12  1964  births_registered   64008

# %%
df_births.drop(columns='label_lc', inplace=True) # drop the label column since we already have our 'births' feature
df_births.head()
# Out:
#     year  births
# 0   1960   60730
# 3   1961   59826
# 6   1962   61611
# 9   1963   62966
# 12  1964   64008

# %%
df_deaths.rename(columns={"value": "deaths"}, inplace=True)
df_deaths.head()
# Out:
#     year           label_lc  deaths
# 1   1960  deaths_registered   32658
# 4   1961  deaths_registered   34548
# 7   1962  deaths_registered   33643
# 10  1963  deaths_registered   33558
# 13  1964  deaths_registered   32473

# %%
df_deaths.drop(columns='label_lc', inplace=True) # drop the label column since we already have our 'deaths' feature
df_deaths.head()
# Out:
#     year  deaths
# 1   1960   32658
# 4   1961   34548
# 7   1962   33643
# 10  1963   33558
# 13  1964   32473

# %%
df_marriages.rename(columns={"value": "marriages"}, inplace=True)
df_marriages.head()
# Out:
#     year              label_lc  marriages
# 2   1960  marriages_registered      15494
# 5   1961  marriages_registered      15140
# 8   1962  marriages_registered      15409
# 11  1963  marriages_registered      15298
# 14  1964  marriages_registered      15941

# %%
df_marriages.drop(columns='label_lc', inplace=True) # drop the label column since we already have our 'marriages' feature
df_marriages.head()
# Out:
#     year  marriages
# 2   1960      15494
# 5   1961      15140
# 8   1962      15409
# 11  1963      15298
# 14  1964      15941

# %%
df_new1 = pd.merge(df_births, df_deaths, how='inner', on='year')
df_new1.head()
# Out:
#    year  births  deaths
# 0  1960   60730   32658
# 1  1961   59826   34548
# 2  1962   61611   33643
# 3  1963   62966   33558
# 4  1964   64008   32473

# %%
df_new = pd.merge(df_new1, df_marriages, how='inner', on='year')
df_new.head()
# Out:
#    year  births  deaths  marriages
# 0  1960   60730   32658      15494
# 1  1961   59826   34548      15140
# 2  1962   61611   33643      15409
# 3  1963   62966   33558      15298
# 4  1964   64008   32473      15941

# %%
df_new.shape
# Out:
# (63, 4)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       63 non-null     int32
#  1   births     63 non-null     int32
#  2   deaths     63 non-null     int32
#  3   marriages  63 non-null     int32
# dtypes: int32(4)
# memory usage: 1.1 KB

# %%
df_new.describe()
# Out:
#               year        births        deaths     marriages
# count    63.000000     63.000000     63.000000     63.000000
# mean   1991.000000  62493.904762  31554.603175  19263.698413
# std      18.330303   7278.289290   1970.121419   2629.056360
# min    1960.000000  47929.000000  27441.000000   9533.000000
# 25%    1975.500000  58162.500000  30437.000000  17335.500000
# 50%    1991.000000  62143.000000  31605.000000  19863.000000
# 75%    2006.500000  67872.000000  33053.000000  21142.500000
# max    2022.000000  75724.000000  35477.000000  23061.000000

# %%
df_new.isnull().mean()*100 # Porcentage of missing data
# Out:
# year         0.0
# births       0.0
# deaths       0.0
# marriages    0.0
# dtype: float64

# %% [markdown]
# ### Loading our dependent feature

# %%
# Source: https://population.un.org/wpp/Download/ (United Nations)
df_target = pd.read_csv('population-with-un-projections.csv')
df_target.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1950
# 1  Afghanistan  AFG  1951
# 2  Afghanistan  AFG  1952
# 3  Afghanistan  AFG  1953
# 4  Afghanistan  AFG  1954
#
#    Population - Sex: all - Age: all - Variant: estimates  \
# 0                                          7480464.0
# 1                                          7571542.0
# 2                                          7667534.0
# 3                                          7764549.0
# 4                                          7864289.0
#
#    Population - Sex: all - Age: all - Variant: medium
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ### Data dictionary

# %% [markdown]
# ##### Entity
# Countries.
#
# ##### Code
# Abbreviation of the countries.
#
# ##### Year
# Years of the values.
#
# ##### Population - Sex: all - Age: all - Variant: estimates
# Values of the population.
#
# ##### Population - Sex: all - Age: all - Variant: medium
# Projections values of the population.

# %%
df_target['Entity'].unique()
# Out:
# array(['Afghanistan', 'Africa (UN)', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia (UN)', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
# ...

# %%
df_target['Code'].unique()
# Out:
# array(['AFG', nan, 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'AIA', 'ATG', 'ARG',
#        'ARM', 'ABW', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB',
#        'BLR', 'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL', 'BES', 'BIH',
#        'BWA', 'BRA', 'VGB', 'BRN', 'BGR', 'BFA', 'BDI', 'KHM', 'CMR',
#        'CAN', 'CPV', 'CYM', 'CAF', 'TCD', 'CHL', 'CHN', 'COL', 'COM',
#        'COG', 'COK', 'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP', 'CZE',
#        'COD', 'DNK', 'DJI', 'DMA', 'DOM', 'TLS', 'ECU', 'EGY', 'SLV',
#        'GNQ', 'ERI', 'EST', 'SWZ', 'ETH', 'FLK', 'FRO', 'FJI', 'FIN',
#        'FRA', 'GUF', 'PYF', 'GAB', 'GMB', 'GEO', 'DEU', 'GHA', 'GIB',
#        'GRC', 'GRL', 'GRD', 'GLP', 'GUM', 'GTM', 'GGY', 'GIN', 'GNB',
#        'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'IRN',
#        'IRQ', 'IRL', 'IMN', 'ISR', 'ITA', 'JAM', 'JPN', 'JEY', 'JOR',
#        'KAZ', 'KEN', 'KIR', 'OWID_KOS', 'KWT', 'KGZ', 'LAO', 'LVA', 'LBN',
# ...

# %% [markdown]
# As we know, the abbreviation for IRELAND is IRL, with this we can extract the desire data.

# %%
df_target = df_target[df_target['Code'].str.contains('IRL')==True]
df_target.head(5)
# Out:
#         Entity Code  Year  \
# 15704  Ireland  IRL  1950
# 15705  Ireland  IRL  1951
# 15706  Ireland  IRL  1952
# 15707  Ireland  IRL  1953
# 15708  Ireland  IRL  1954
#
#        Population - Sex: all - Age: all - Variant: estimates  \
# 15704                                          2906608.0
# 15705                                          2924713.0
# 15706                                          2929379.0
# 15707                                          2917036.0
# 15708                                          2902783.0
#
#        Population - Sex: all - Age: all - Variant: medium
# 15704                                                NaN
# 15705                                                NaN
# 15706                                                NaN
# 15707                                                NaN
# 15708                                                NaN

# %%
df_target.describe()
# Out:
#               Year  Population - Sex: all - Age: all - Variant: estimates  \
# count   151.000000                                       7.200000e+01
# mean   2025.000000                                       3.571422e+06
# std      43.734045                                       6.702954e+05
# min    1950.000000                                       2.807012e+06
# 25%    1987.500000                                       2.922833e+06
# 50%    2025.000000                                       3.488154e+06
# 75%    2062.500000                                       3.977020e+06
# max    2100.000000                                       4.986525e+06
#
#        Population - Sex: all - Age: all - Variant: medium
# count                                       7.900000e+01
# mean                                        5.636562e+06
# std                                         2.158079e+05
# min                                         5.023108e+06
# ...

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 15704 to 15854
# Data columns (total 5 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Entity                                                 151 non-null    object
#  1   Code                                                   151 non-null    object
#  2   Year                                                   151 non-null    int64
#  3   Population - Sex: all - Age: all - Variant: estimates  72 non-null     float64
#  4   Population - Sex: all - Age: all - Variant: medium     79 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 7.1+ KB

# %%
df_target.isnull().mean()*100 # Porcentage of missing data
# Out:
# Entity                                                    0.000000
# Code                                                      0.000000
# Year                                                      0.000000
# Population - Sex: all - Age: all - Variant: estimates    52.317881
# Population - Sex: all - Age: all - Variant: medium       47.682119
# dtype: float64

# %% [markdown]
# We need to cut our dataset our target dataset because it goes from 1950 to 2100 and our analysis is from 1960 to 2022, then we require to have all the population values in the same feature.

# %%
df_target = df_target[df_target['Year'] >= 1960]
df_target = df_target[df_target['Year'] <= 2022]
df_target = df_target.drop(columns =['Entity','Code'], axis=1)
df_target.columns= ['year', 'pop', 'pop1']
df_target.head()
# Out:
#        year        pop  pop1
# 15714  1960  2811075.0   NaN
# 15715  1961  2807012.0   NaN
# 15716  1962  2813072.0   NaN
# 15717  1963  2824097.0   NaN
# 15718  1964  2837439.0   NaN

# %%
df_target.fillna(0,inplace=True)
df_target['population'] = df_target['pop']+df_target['pop1']
df_target['population'] = df_target['population'].astype('int')
df_target.head()
# Out:
#        year        pop  pop1  population
# 15714  1960  2811075.0   0.0     2811075
# 15715  1961  2807012.0   0.0     2807012
# 15716  1962  2813072.0   0.0     2813072
# 15717  1963  2824097.0   0.0     2824097
# 15718  1964  2837439.0   0.0     2837439

# %%
df_target = df_target.drop(columns =['pop','pop1'], axis=1)
df_target.shape
# Out:
# (63, 2)

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, 15714 to 15776
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        63 non-null     int64
#  1   population  63 non-null     int32
# dtypes: int32(1), int64(1)
# memory usage: 1.2 KB

# %%
df_target.describe()
# Out:
#               year    population
# count    63.000000  6.300000e+01
# mean   1991.000000  3.703371e+06
# std      18.330303  6.743050e+05
# min    1960.000000  2.807012e+06
# 25%    1975.500000  3.181838e+06
# 50%    1991.000000  3.515672e+06
# 75%    2006.500000  4.297325e+06
# max    2022.000000  5.023108e+06

# %%
df_target
df_target.head(10)
# Out:
#        year  population
# 15714  1960     2811075
# 15715  1961     2807012
# 15716  1962     2813072
# 15717  1963     2824097
# 15718  1964     2837439
# 15719  1965     2852404
# 15720  1966     2867008
# 15721  1967     2882744
# 15722  1968     2899653
# 15723  1969     2917193

# %% [markdown]
# At this point, we have our target dataset and our independent features dataset, we can now merge both to be able to proceed with further analysis and with our Machine Learning model.

# %%
df_new = pd.merge(df_new, df_target, how='inner', on='year')
df_new.head()
# Out:
#    year  births  deaths  marriages  population
# 0  1960   60730   32658      15494     2811075
# 1  1961   59826   34548      15140     2807012
# 2  1962   61611   33643      15409     2813072
# 3  1963   62966   33558      15298     2824097
# 4  1964   64008   32473      15941     2837439

# %%
df_new.isnull().mean()*100 # Porcentage of missing data
# Out:
# year          0.0
# births        0.0
# deaths        0.0
# marriages     0.0
# population    0.0
# dtype: float64

# %%
df_new.shape
# Out:
# (63, 5)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        63 non-null     int32
#  1   births      63 non-null     int32
#  2   deaths      63 non-null     int32
#  3   marriages   63 non-null     int32
#  4   population  63 non-null     int32
# dtypes: int32(5)
# memory usage: 1.4 KB

# %%
df_new.describe()
# Out:
#               year        births        deaths     marriages    population
# count    63.000000     63.000000     63.000000     63.000000  6.300000e+01
# mean   1991.000000  62493.904762  31554.603175  19263.698413  3.703371e+06
# std      18.330303   7278.289290   1970.121419   2629.056360  6.743050e+05
# min    1960.000000  47929.000000  27441.000000   9533.000000  2.807012e+06
# 25%    1975.500000  58162.500000  30437.000000  17335.500000  3.181838e+06
# 50%    1991.000000  62143.000000  31605.000000  19863.000000  3.515672e+06
# 75%    2006.500000  67872.000000  33053.000000  21142.500000  4.297325e+06
# max    2022.000000  75724.000000  35477.000000  23061.000000  5.023108e+06

# %%
df_new['population'].describe().apply('{0:.2f}'.format) # Descriptive statistics formatted for a better understanding
# Out:
# count         63.00
# mean     3703370.56
# std       674305.01
# min      2807012.00
# 25%      3181837.50
# 50%      3515672.00
# 75%      4297325.00
# max      5023108.00
# Name: population, dtype: object

# %%
sns.scatterplot(data=df_new, x='year', y='population')
# Out:
# <Axes: xlabel='year', ylabel='population'>

# %%
sns.scatterplot(data=df_new.iloc[:,1:4])
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_new.iloc[:,1:3])
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_new.iloc[:,[1,3]])
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_new, x='year', y='births')
# Out:
# <Axes: xlabel='year', ylabel='births'>

# %%
sns.scatterplot(data=df_new, x='year', y='deaths')
# Out:
# <Axes: xlabel='year', ylabel='deaths'>

# %%
sns.scatterplot(data=df_new, x='year', y='marriages')
# Out:
# <Axes: xlabel='year', ylabel='marriages'>

# %% [markdown]
# ### Machine Learning models

# %%
X = df_new.iloc[:,0:4]
y = df_new['population']

# %%
X.shape, y.shape
# Out:
# ((63, 4), (63,))

# %% [markdown]
# ###  Random Forest Regressor:
# To perform a Hyperparameter tuning we can use the Grid Search library to help us iterate multiple values of parameters through the Machine Learning model, furthermore, we will use the TimeSeriesSplit (a cross validation technique) library from sklearn to help us confirm that our model is performing well.

# %%
time_ss = TimeSeriesSplit(n_splits=5) # Default number of splits

# %%
tuning_grid = {
    'n_estimators': [10, 20, 30, 40, 50],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 5, 7, 9],
    'min_samples_leaf': [1, 2, 3, 4],
    'max_leaf_nodes': [3, 4, 5, 6, 7, 8, 9]  
}

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X, y, test_size=0.10, random_state=4)
X1_train.shape, X1_test.shape, y1_train.shape, y1_test.shape
# Out:
# ((56, 4), (7, 4), (56,), (7,))

# %%
grid_search1 = GridSearchCV(RandomForestRegressor(), 
                           param_grid=tuning_grid, scoring='r2', cv=time_ss) 
grid_search1.fit(X1_train, y1_train) 
print(grid_search1.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=7, max_features=None, max_leaf_nodes=8,
#                       n_estimators=10)

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X, y, test_size=0.20, random_state=4)
X2_train.shape, X2_test.shape, y2_train.shape, y2_test.shape
# Out:
# ((50, 4), (13, 4), (50,), (13,))

# %%
grid_search2 = GridSearchCV(RandomForestRegressor(), 
                           param_grid=tuning_grid, scoring='r2', cv=time_ss) 
grid_search2.fit(X2_train, y2_train) 
print(grid_search2.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=9, max_features=None, max_leaf_nodes=8,
#                       min_samples_leaf=2, n_estimators=10)

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(X, y, test_size=0.30, random_state=4)
X3_train.shape, X3_test.shape, y3_train.shape, y3_test.shape
# Out:
# ((44, 4), (19, 4), (44,), (19,))

# %%
grid_search3 = GridSearchCV(RandomForestRegressor(), 
                           param_grid=tuning_grid, scoring='r2', cv=time_ss) 
grid_search3.fit(X3_train, y3_train) 
print(grid_search3.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=5, max_features=None, max_leaf_nodes=6,
#                       n_estimators=20)

# %%
print('Best Hyperparameters (90% training):',grid_search1.best_params_)
print('Best Score (90% training):',grid_search1.best_score_)
print('Best Hyperparameters (80% training):',grid_search2.best_params_)
print('Best Score (80% training):',grid_search2.best_score_)
print('Best Hyperparameters (70% training):',grid_search3.best_params_)
print('Best Score (70% training):',grid_search3.best_score_)
# Out:
# Best Hyperparameters (90% training): {'max_depth': 7, 'max_features': None, 'max_leaf_nodes': 8, 'min_samples_leaf': 1, 'n_estimators': 10}
# Best Score (90% training): 0.8710596650760722
# Best Hyperparameters (80% training): {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 8, 'min_samples_leaf': 2, 'n_estimators': 10}
# Best Score (80% training): 0.9081010483272763
# Best Hyperparameters (70% training): {'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 6, 'min_samples_leaf': 1, 'n_estimators': 20}
# Best Score (70% training): 0.9033935824073126

# %% [markdown]
# ### R2 scores comparison (Training v Testing):

# %%
RF1 = grid_search1.best_estimator_
RF1.fit(X1_train, y1_train)
train1_pred = RF1.predict(X1_train)
y1_pred = RF1.predict(X1_test)
train1_result = r2_score(y1_train, train1_pred)
test1_result = r2_score(y1_test, y1_pred)
print('r2_score result (training)(90% training):',train1_result)
print('r2_score result (testing)(90% training):',test1_result)

train1_r_mae = metrics.mean_absolute_error(y1_train, train1_pred)
test1_r_mae = metrics.mean_absolute_error(y1_test, y1_pred)
print('Mean Absolute Error result (training)(90% training):',train1_r_mae)
print('Mean Absolute Error (testing)(90% training):',test1_r_mae)
# Out:
# r2_score result (training)(90% training): 0.9961770755927559
# r2_score result (testing)(90% training): 0.9934987069110169
# Mean Absolute Error result (training)(90% training): 35301.692551015396
# Mean Absolute Error (testing)(90% training): 36554.07867604621

# %%
RF2 = grid_search2.best_estimator_
RF2.fit(X2_train, y2_train)
train2_pred = RF2.predict(X2_train)
y2_pred = RF2.predict(X2_test)
train2_result = r2_score(y2_train, train2_pred)
test2_result = r2_score(y2_test, y2_pred)
print('r2_score result (training)(80% training):',train2_result)
print('r2_score result (testing)(80% training):',test2_result)

train2_r_mae = metrics.mean_absolute_error(y2_train, train2_pred)
test2_r_mae = metrics.mean_absolute_error(y2_test, y2_pred)
print('Mean Absolute Error result (training)(80% training):',train2_r_mae)
print('Mean Absolute Error (testing)(80% training):',test2_r_mae)
# Out:
# r2_score result (training)(80% training): 0.9960138464881054
# r2_score result (testing)(80% training): 0.9975280261057896
# Mean Absolute Error result (training)(80% training): 34948.74901261241
# Mean Absolute Error (testing)(80% training): 19170.221608423664

# %%
RF3 = grid_search3.best_estimator_
RF3.fit(X3_train, y3_train)
train3_pred = RF3.predict(X3_train)
y3_pred = RF3.predict(X3_test)
train3_result = r2_score(y3_train, train3_pred)
test3_result = r2_score(y3_test, y3_pred)
print('r2_score result (training)(70% training):',train3_result)
print('r2_score result (testing)(70% training):',test3_result)

train3_r_mae = metrics.mean_absolute_error(y3_train, train3_pred)
test3_r_mae = metrics.mean_absolute_error(y3_test, y3_pred)
print('Mean Absolute Error result (training)(70% training):',train3_r_mae)
print('Mean Absolute Error (testing)(70% training):',test3_r_mae)
# Out:
# r2_score result (training)(70% training): 0.9915239678991832
# r2_score result (testing)(70% training): 0.9873006098546017
# Mean Absolute Error result (training)(70% training): 51887.22138677142
# Mean Absolute Error (testing)(70% training): 42781.05450523154

# %% [markdown]
# ### Feature importances:

# %% [markdown]
# 90% training

# %%
features1 = pd.DataFrame(RF1.feature_importances_).T
features1.columns = X.columns
features1
# Out:
#        year    births    deaths  marriages
# 0  0.978306  0.007688  0.010594   0.003412

# %% [markdown]
# 80% training

# %%
features2 = pd.DataFrame(RF2.feature_importances_).T
features2.columns = X.columns
features2
# Out:
#        year    births    deaths  marriages
# 0  0.983029  0.012889  0.003618   0.000464

# %% [markdown]
# 70% training

# %%
features3 = pd.DataFrame(RF3.feature_importances_).T
features3.columns = X.columns
features3
# Out:
#        year    births    deaths  marriages
# 0  0.977965  0.007935  0.011636   0.002465

# %% [markdown]
# In our RandomForestRegressor 3, which has a 70% of training data, we can observe that the 'deaths' feature has a higher importance than in the other 2 models, this is particularly relevant knowing that since 2005-2006 (in our 'years-deaths' plot) the number of deaths in Ireland are rising and reaching all time highs in recent years.

# %%
features3.plot(kind='bar', title='RandomForestRegressor with 70% of data as training');

# %% [markdown]
# We can observe that our ‘year’ feature is the main determining factor in our data, nevertheless, knowing the rapid rising of deaths in Ireland, we can understand why our model is taking ‘deaths’ feature as the second more important feature to predict the population in Ireland, in future years we can anticipate that this feature will gain more relevance.

# %% [markdown]
# After seeing our r2 scores and Mean Absolute Percentage Errors, we are concerned about data leakage from our 'births' and 'deaths' features, therefore, we will only keep our 'year' feature and re-train our Random Forest Regressor model to compare the metrics.

# %%
X.drop({'births','deaths', 'marriages'}, axis=1, inplace=True)

# %%
X
# Out:
#     year
# 0   1960
# 1   1961
# 2   1962
# 3   1963
# 4   1964
# ..   ...
# 58  2018
# 59  2019
# 60  2020
# 61  2021
# 62  2022
#
# [63 rows x 1 columns]

# %%
grid_search_noSplit = GridSearchCV(RandomForestRegressor(), 
                           param_grid=tuning_grid, scoring='r2', cv=time_ss) 
grid_search_noSplit.fit(X, y) 
print(grid_search_noSplit.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=5, max_features='log2', max_leaf_nodes=9,
#                       n_estimators=10)

# %%
XCheck_train, XCheck_test, yCheck_train, yCheck_test = train_test_split(X, y, test_size=0.20, random_state=4)
XCheck_train.shape, XCheck_test.shape, yCheck_train.shape, yCheck_test.shape
# Out:
# ((50, 1), (13, 1), (50,), (13,))

# %%
RF_check = grid_search_noSplit.best_estimator_
RF_check.fit(XCheck_train, yCheck_train)
train_pred = RF_check.predict(XCheck_train)
y_pred = RF_check.predict(XCheck_test)
train_result = r2_score(yCheck_train, train_pred)
test_result = r2_score(yCheck_test, y_pred)
print('r2_score result (training)(80% training):',train_result)
print('r2_score result (testing)(80% training):',test_result)

train_r_mae = metrics.mean_absolute_error(yCheck_train, train_pred)
test_r_mae = metrics.mean_absolute_error(yCheck_test, y_pred)
print('Mean Absolute Error result (training)(80% training):',train_r_mae)
print('Mean Absolute Error (testing)(80% training):',test_r_mae)
# Out:
# r2_score result (training)(80% training): 0.9975450434681913
# r2_score result (testing)(80% training): 0.9967676351862307
# Mean Absolute Error result (training)(80% training): 27635.60876197691
# Mean Absolute Error (testing)(80% training): 20784.499092019163

# %% [markdown]
# Even after only keeping the 'year' feature to prevent any data leakage, our model keeps performing well, this could be due to the most important feature by far is 'year'.

# %% [markdown]
# ### Second approach

# %% [markdown]
# Following our initial understanding of our data and feature importances using the Random Forest Regressor algorithm, we will compare how well ARIMA and SARIMA models fit in our data.
#
# In this new approach, considering that our data type is time series, using our target feature (Population) we will make sure that our data is stationary before training our models.
#
# Time Series is a way of studying the characteristics of the response variable concerning time as the independent variable. To estimate the target variable in forecasting, we use the time variable as the reference point (Pandian, 2021).

# %%
# Function to plot and check our time series data
def plot_time_series(xt, nlag = 100, fig_size = (10,8)):
    if not isinstance(xt, pd.Series):
        xt = pd.Series(xt)
    plt.figure(figsize = fig_size)
    layout = (2,2)

    ax_xt = plt.subplot2grid(layout, (0,0), colspan = 2) # It will take 2 column spaces
    ax_acf = plt.subplot2grid(layout, (1,0))
    ax_pacf = plt.subplot2grid(layout, (1,1))

    xt.plot(ax = ax_xt)
    ax_xt.set_title('Time Series', fontdict = {'fontsize':18})
    plot_acf(xt, lags = 50, ax = ax_acf)
    plot_pacf(xt, lags = 29, ax = ax_pacf)
    plt.tight_layout() # Adjust the padding between and around subplots
    return None

# %%
df_new
# Out:
#     year  births  deaths  marriages  population
# 0   1960   60730   32658      15494     2811075
# 1   1961   59826   34548      15140     2807012
# 2   1962   61611   33643      15409     2813072
# 3   1963   62966   33558      15298     2824097
# 4   1964   64008   32473      15941     2837439
# ..   ...     ...     ...        ...         ...
# 58  2018   61016   31116      21101     4834506
# 59  2019   59796   31134      20452     4896021
# 60  2020   55959   31765       9533     4946123
# 61  2021   58443   33055      17230     4986525
# 62  2022   57540   35477      23061     5023108
#
# [63 rows x 5 columns]

# %%
# We will put our 'year' feature as index to perform the time series analysis
df_new['year'] = pd.to_datetime(df_new['year'], format = '%Y')
df_new.index = df_new['year']
df_new.drop('year', axis = 1, inplace = True) # Since we now have our index based on the year, we do not longer need our 'year' feature

# %%
df_new
# Out:
#             births  deaths  marriages  population
# year
# 1960-01-01   60730   32658      15494     2811075
# 1961-01-01   59826   34548      15140     2807012
# 1962-01-01   61611   33643      15409     2813072
# 1963-01-01   62966   33558      15298     2824097
# 1964-01-01   64008   32473      15941     2837439
# ...            ...     ...        ...         ...
# 2018-01-01   61016   31116      21101     4834506
# 2019-01-01   59796   31134      20452     4896021
# 2020-01-01   55959   31765       9533     4946123
# 2021-01-01   58443   33055      17230     4986525
# 2022-01-01   57540   35477      23061     5023108
#
# [63 rows x 4 columns]

# %% [markdown]
# Now we need to visualise the Autocorrelation and Partial Autorcorrelation of our data.
#
# Autocorrelation (ACF): Calculation of the correlation of the time series observations with values of the same series, but at previous times.
#
# Partial Autocorrelation (PACF): Summarises the relationship between an observation in a time series with observations at previous time steps, but the relationships of intervening observations are removed.
#
# (Marv, 2021)

# %%
plot_time_series(df_new['population'], nlag = 100)

# %% [markdown]
# From these plots, we are looking at the point outside the blue shadow, that means that they have statistical significance, that indicates that an observed relationship is unlikely to be due to chance.
#
# Let's see if our data is stationary or not by performing a Dickey Fuller test.

# %%
fuller_result = adfuller(df_new.population.to_list())
print('ADF Statistic %f' % fuller_result[0])
print('p-value %f' % fuller_result[1])
# Out:
# ADF Statistic 0.332937
# p-value 0.978806

# %% [markdown]
# Since we got a p-value of almost 1, we can say that our data is not stationary, therefore, we will use the differencing method to make it stationary.

# %%
first_differencing = df_new['population'].diff().dropna()

# %%
fuller_result = adfuller(first_differencing)

print('ADF Statistic: %f' % fuller_result[0])
print('p-value: %f' % fuller_result[1])
# Out:
# ADF Statistic: -1.997019
# p-value: 0.287882

# %% [markdown]
# As we can see, our p-value is more than 0.05, we can say that our data is not stationary, hence, we will need to perform the second-order differencing method.

# %%
second_differencing = df_new['population'].diff().diff().dropna()

# %%
plot_time_series(second_differencing, nlag = 100)
fuller_result = adfuller(second_differencing)

print('ADF Statistic: %f' % fuller_result[0])
print('p-value: %f' % fuller_result[1])
# Out:
# ADF Statistic: -3.751226
# p-value: 0.003448

# %% [markdown]
# After performing the second-order differencing method we got a p-value of 0.0034, with that we can conclude that our data is now stationary.

# %%
fig, ax = plt.subplots(2, sharex = True);
fig.set_size_inches(10,4);

df_new['population'].plot(ax = ax[0], color = 'b');
ax[0].set_title('Population');

second_differencing.plot(ax = ax[1], color = 'g');
ax[1].set_title('Population after second-order differencing method');

# %% [markdown]
# Firstly we will use the ARIMA algorithm, this algorithm is used to understand past data or predict into the future. To find the best values for our ARIMA algorithm, we will now create a function to iterate multiple values through the algorithm, we are looking for the lowest Akaike's Information Criterion (AIC).

# %% [markdown]
# #### ARIMA

# %%
aicValues = []

for d in range(1,3):
    for ari in range(0,3):
        for maj in range(0,3):
            try:
                arima_obj = ARIMA(df_new['population'].tolist(), order=(ari,d,maj))
                arima_obj_fit = arima_obj.fit()
                aicValues.append([ari, d, maj, arima_obj_fit.aic])

            except ValueError:
                pass

print(aicValues)
# Out:
# [[0, 1, 0, 3284920.187009365], [0, 1, 1, 1507.2419545005848], [0, 1, 2, 1508.4243481549865], [1, 1, 0, 1507.1048702650623], [1, 1, 1, 1518.1263630807903], [1, 1, 2, 2303.3395785201487], [2, 1, 0, 3166.6295823358573], [2, 1, 1, 4431.6297352633965], [2, 1, 2, 2117.892575195458], [0, 2, 0, 172476.04151286883], [0, 2, 1, 1337.6369724971323], [0, 2, 2, 1784.5478769276467], [1, 2, 0, 1322.9493209258897], [1, 2, 1, 1359.0080473180674], [1, 2, 2, 1358.303262310622], [2, 2, 0, 1373.0114340499085], [2, 2, 1, 1393.864531016224], [2, 2, 2, 1403.3901413335975]]

# %%
bestaic = pd.DataFrame(aicValues).groupby(by=[3]).min().head(1)

# %%
print('Best AIC values: ', bestaic.values, bestaic.index)
# Out:
# Best AIC values:  [[1 2 0]] Index([1322.9493209258897], dtype='float64', name=3)

# %%
bestaic_values = bestaic.values
bestaic_values = pd.DataFrame(bestaic_values)

# %%
mylist = []
for i in range(len(bestaic_values)):
    mylist.append(bestaic_values.iloc[i,0])
    mylist.append(bestaic_values.iloc[i,1])
    mylist.append(bestaic_values.iloc[i,2])

mylist
# Out:
# [1, 2, 0]

# %%
tuple(mylist)
# Out:
# (1, 2, 0)

# %%
arima_obj = ARIMA(df_new['population'].tolist(), order=(tuple(mylist)))
arima_obj_fit = arima_obj.fit()

# %%
pred_arima = arima_obj_fit.fittedvalues

df_new['ARIMA_pred'] = pred_arima
diffval = arima_obj_fit.resid + arima_obj_fit.fittedvalues # The result would be the actual population
df_new['diffval'] = diffval
df_new
# Out:
#             births  deaths  marriages  population    ARIMA_pred    diffval
# year
# 1960-01-01   60730   32658      15494     2811075  0.000000e+00  2811075.0
# 1961-01-01   59826   34548      15140     2807012  5.573173e+06  2807012.0
# 1962-01-01   61611   33643      15409     2813072  2.811299e+06  2813072.0
# 1963-01-01   62966   33558      15298     2824097  2.819101e+06  2824097.0
# 1964-01-01   64008   32473      15941     2837439  2.835107e+06  2837439.0
# ...            ...     ...        ...         ...           ...        ...
# 2018-01-01   61016   31116      21101     4834506  4.827911e+06  4834506.0
# 2019-01-01   59796   31134      20452     4896021  4.897132e+06  4896021.0
# 2020-01-01   55959   31765       9533     4946123  4.957539e+06  4946123.0
# 2021-01-01   58443   33055      17230     4986525  4.996260e+06  4986525.0
# 2022-01-01   57540   35477      23061     5023108  5.026957e+06  5023108.0
#
# [63 rows x 6 columns]

# %% [markdown]
# Now that we have our ARIMA model, let's compare the actual population vs the ARIMA forecast.

# %%
ax_f, axr = plt.subplots(1, sharex=True);
ax_f.set_size_inches(12, 5);

df_new['diffval'].iloc[2:].plot(color='dimgray', linestyle='-', ax=axr, label='Actual');
df_new['ARIMA_pred'].iloc[2:].plot(color='red', linestyle='--', ax=axr, label='ARIMA Forecast');
axr.set_title('ARIMA', fontdict={'fontsize':18});
axr.set_xlabel('Year');
axr.set_ylabel('Population');
axr.legend();

# %% [markdown]
# #### SARIMA

# %% [markdown]
# In order to find the seasonal order for our SARIMA model, we will use the 'pmdarima' library as follows.

# %%
seasonal = pm.auto_arima(df_new.population, d=0, start_p=0, start_q=0, max_p=4, max_q=4, seasonal=True, m=4, D=2, startP=1, start_Q=1,
                        max_P=4, max_Q=4, information_criterion='aic', trace=True, stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(1,2,1)[4]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,0)(0,2,0)[4]             : AIC=1428.582, Time=0.01 sec
#  ARIMA(1,0,0)(1,2,0)[4]             : AIC=1530.504, Time=0.05 sec
#  ARIMA(0,0,1)(0,2,1)[4]             : AIC=1427.739, Time=0.02 sec
#  ARIMA(0,0,1)(0,2,0)[4]             : AIC=1428.504, Time=0.03 sec
#  ARIMA(0,0,1)(1,2,1)[4]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,1)(0,2,2)[4]             : AIC=1425.343, Time=0.08 sec
#  ARIMA(0,0,1)(1,2,2)[4]             : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,1)(0,2,3)[4]             : AIC=1426.144, Time=0.07 sec
#  ARIMA(0,0,1)(1,2,3)[4]             : AIC=1428.123, Time=0.11 sec
#  ARIMA(0,0,0)(0,2,2)[4]             : AIC=1431.036, Time=0.03 sec
#  ARIMA(1,0,1)(0,2,2)[4]             : AIC=1289.935, Time=0.11 sec
#  ARIMA(1,0,1)(0,2,1)[4]             : AIC=1294.187, Time=0.09 sec
#  ARIMA(1,0,1)(1,2,2)[4]             : AIC=1290.959, Time=0.31 sec
# ...

# %%
seasonal = seasonal.get_params()
seasonal = pd.DataFrame(seasonal.items())

# %%
seasonal
# Out:
#                      0             1
# 0              maxiter            50
# 1               method         lbfgs
# 2                order     (2, 0, 2)
# 3   out_of_sample_size             0
# 4              scoring           mse
# 5         scoring_args            {}
# 6       seasonal_order  (1, 2, 1, 4)
# 7         start_params          None
# 8    suppress_warnings          True
# 9                trend          None
# 10      with_intercept         False

# %%
order_value_sarima = pd.DataFrame(seasonal.iloc[2:3,1])
seasonal_values_sarima = pd.DataFrame(seasonal.iloc[6:7,1])

# %%
order_value_sarima = order_value_sarima.iloc[0].astype('string').str.split(', ', expand=True)
seasonal_values_sarima = seasonal_values_sarima.iloc[0].astype('string').str.split(', ', expand=True)

# %%
order_value_sarima[0] = order_value_sarima[0].str.replace('(','')
order_value_sarima[2] = order_value_sarima[2].str.replace(')','')

seasonal_values_sarima[0] = seasonal_values_sarima[0].str.replace('(','')
seasonal_values_sarima[2] = seasonal_values_sarima[2].str.replace(')','')

# %%
sarima_best_model = SARIMAX(df_new['population'], order=tuple(order_value_sarima), seasonal_order=tuple(seasonal_values_sarima)).fit()

# %%
pred_sarima = sarima_best_model.fittedvalues

df_new['SARIMA_pred'] = pred_sarima
diffval_sarima = sarima_best_model.resid + sarima_best_model.fittedvalues # The result would be the actual population
df_new['diffval_sarima'] = diffval_sarima
df_new
# Out:
#             births  deaths  marriages  population    ARIMA_pred    diffval  \
# year
# 1960-01-01   60730   32658      15494     2811075  0.000000e+00  2811075.0
# 1961-01-01   59826   34548      15140     2807012  5.573173e+06  2807012.0
# 1962-01-01   61611   33643      15409     2813072  2.811299e+06  2813072.0
# 1963-01-01   62966   33558      15298     2824097  2.819101e+06  2824097.0
# 1964-01-01   64008   32473      15941     2837439  2.835107e+06  2837439.0
# ...            ...     ...        ...         ...           ...        ...
# 2018-01-01   61016   31116      21101     4834506  4.827911e+06  4834506.0
# 2019-01-01   59796   31134      20452     4896021  4.897132e+06  4896021.0
# 2020-01-01   55959   31765       9533     4946123  4.957539e+06  4946123.0
# 2021-01-01   58443   33055      17230     4986525  4.996260e+06  4986525.0
# 2022-01-01   57540   35477      23061     5023108  5.026957e+06  5023108.0
#
#              SARIMA_pred  diffval_sarima
# year
# ...

# %%
ax_f, axr = plt.subplots(1, sharex=True);
ax_f.set_size_inches(12, 5);

df_new['diffval_sarima'].iloc[4:].plot(color='dimgray', linestyle='-', ax=axr, label='Actual');
df_new['SARIMA_pred'].iloc[4:].plot(color='mediumblue', linestyle='-.', ax=axr, label='SARIMA Forecast');
axr.set_title('SARIMA', fontdict={'fontsize':18});
axr.set_xlabel('Year');
axr.set_ylabel('Population');
axr.legend();

# %%
ax_f, axr = plt.subplots(1, sharex=True);
ax_f.set_size_inches(12, 5);

df_new['diffval_sarima'].iloc[4:].plot(color='dimgray', linestyle='-', ax=axr, label='Actual');
df_new['ARIMA_pred'].iloc[4:].plot(color='red', linestyle='--', ax=axr, label='ARIMA Forecast');
df_new['SARIMA_pred'].iloc[4:].plot(color='mediumblue', linestyle='-.', ax=axr, label='SARIMA Forecast');
axr.set_title('ARIMA & SARIMA', fontdict={'fontsize':18});
axr.set_xlabel('Year');
axr.set_ylabel('Population');
axr.legend();

# %% [markdown]
# Even though our ARIMA model seems to fit better than our SARIMA model, we already know that seasonality its being created as time goes on from our EDA, therefore, we can say that our SARIMA model performs better than our ARIMA model for forecasting population based on the data that we have, let's make a forecast of population for the next 8 years with our SARIMA and Random Forest Regressor model.

# %%
sarima_best_model.plot_diagnostics(figsize=(10,7));

# %% [markdown]
# The correlogram suggest that there is no autocorrelation in the residuals, hence, they can be considered as 'white noise' or irrelevant, these residuals are the differences between the fitted model and the actual data, the closer to 0 the better.

# %%
forecast_sarima = sarima_best_model.get_forecast(steps = 8)
pd.DataFrame(forecast_sarima.predicted_mean)
# Out:
#             predicted_mean
# 2023-01-01    5.073264e+06
# 2024-01-01    5.113758e+06
# 2025-01-01    5.150425e+06
# 2026-01-01    5.200597e+06
# 2027-01-01    5.241152e+06
# 2028-01-01    5.277887e+06
# 2029-01-01    5.328059e+06
# 2030-01-01    5.368613e+06

# %%
rf_values_pred = {'year': list(range(2023,2031))}
rf_values_pred = pd.DataFrame(rf_values_pred)

# %%
results_forecast_RF = []
i=1
n=0
for value in rf_values_pred['year']:
    ran = pd.DataFrame(rf_values_pred['year'].iloc[n:i])
    rf_pred = RF_check.predict(ran)
    results_forecast_RF.append(rf_pred)
    i = i+1
    n = n+1

results_forecast_RF
# Out:
# [array([4952848.28083333]),
#  array([4952848.28083333]),
#  array([4952848.28083333]),
#  array([4952848.28083333]),
#  array([4952848.28083333]),
#  array([4952848.28083333]),
#  array([4952848.28083333]),
#  array([4952848.28083333])]

# %% [markdown]
# As we can see, when we try to make a forecast using our Random Forest Regressor, it is not able to perform even though it got quite good scores while training and testing.
#
# This problem can be explained, Random Forest Regressor will always predict an average of the values seen previously, therefore, is unable to discover trends that would enable it to perform in this type of scenarios (Mwiti, 2020).

# %% [markdown]
# Lastly, we can now visualise our population forecast for the years 2023 to 2030 using our SARIMA model.

# %%
forecast_sarima = sarima_best_model.get_forecast(steps = 8)
forecast_confidence = forecast_sarima.conf_int()

f, ax = plt.subplots(1, sharex=True)


df_new['population'].iloc[3:].plot(color='dimgray', linestyle='-', ax=ax, label='Actual')

forecast_sarima.predicted_mean.plot(ax=ax, label='SARIMA Forecast', figsize=(10,5), grid=True, linestyle='-.')
ax.fill_between(forecast_confidence.index, forecast_confidence.iloc[:,0],
               forecast_confidence.iloc[:,1], color = 'yellow', alpha=0.5)
ax.text(1,.92,'Forecasted values until 2030', fontsize=8.8, color='red', transform=ax.transAxes, va='top', ha='right')
plt.ylabel('Population')
plt.title('Population in Ireland per year (year 2030)')
plt.xlabel('Year')


plt.show()

# %% [markdown]
# Now that we have our forecast visualisation, we can make a forecast until 2100 and compare it with the projections from the United Nations World Population data.

# %%
forecast_sarima = sarima_best_model.get_forecast(steps = 78) # Forecast year 2100
forecast_confidence = forecast_sarima.conf_int()

f, ax = plt.subplots(1, sharex=True)


df_new['population'].iloc[3:].plot(color='dimgray', linestyle='-', ax=ax, label='Actual')

forecast_sarima.predicted_mean.plot(ax=ax, label='SARIMA Forecast', figsize=(10,5), grid=True, linestyle='-.')
ax.fill_between(forecast_confidence.index, forecast_confidence.iloc[:,0],
               forecast_confidence.iloc[:,1], color = 'yellow', alpha=0.5)
ax.text(1,.58,'Forecasted values until 2100', fontsize=8.8, color='red', transform=ax.transAxes, va='top', ha='right')
plt.ylabel('Population')
plt.title('Population in Ireland per year (year 2100)')
plt.xlabel('Year')


plt.show()

# %% [markdown]
# #### High fertility scenario

# %% [markdown]
# ![UN projections - population in Ireland (High).png](attachment:85b0badc-63c0-45a0-9ed7-26363565beff.png)

# %% [markdown]
# #### Low fertility scenario

# %% [markdown]
# ![UN projections - population in Ireland (Low).png](attachment:89b5d707-66eb-4000-aff3-cf52fdf40cfd.png)

# %% [markdown]
# Source: https://ourworldindata.org/population-growth#explore-data-poverty

# %% [markdown]
# With the above comparison, we can confirm that our SARIMA model is performing well, our projections are quite similar to the UN high fertility projections and our bottom line of our confidence interval follows the UN low fertility projections.

# %% [markdown]
# ### GitHub

# %% [markdown]
# https://github.com/LeopoldoCCT/Strategic_Thinking_
